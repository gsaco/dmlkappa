# %%
# Imports
from dmlkappa.simulation import simulate_plr_once, fit_dml_plr, run_plr_simulation_grid
from dmlkappa.diagnostics import diagnostic_report, diagnostic_from_u
from dmlkappa.plotting import plot_kappa_vs_coverage, plot_kappa_hist
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Single Dataset Example

# %%
n = 500
overlap = "moderate"
rho = 0.5

Y, D, X = simulate_plr_once(n=n, overlap=overlap, rho=rho, random_state=123)
out = fit_dml_plr(Y, D, X, n_folds=5, random_state=123)

print("theta_hat:", out["theta_hat"])
print("SE_hat:", out["se_hat"])
print("95% CI:", out["ci"])
print("kappa:", out["kappa"])
# Out:
# theta_hat: 0.883462523771826
# SE_hat: 0.0468642850004501
# 95% CI: (0.7916085251709438, 0.9753165223727082)
# kappa: 0.9519196538573136

# %%
# Diagnostic report
print(diagnostic_report(out["kappa"], n))
# Out:
# κ_DML = 0.9519 (n = 500)
# Regime: well_conditioned
# Heuristic effective sample size: n_eff ≈ 262.31
# Recommendation: inference appears well-conditioned; standard DML SEs are likely reliable.
# See note.tex and derivations.tex for detailed justification and proofs.

# %% [markdown]
# ## 2. Simulation Grid

# %%
n_list = [200, 500]
overlap_list = ["moderate", "low"]
rho_list = [0.2, 0.5]
n_rep = 10

results_df, summary_df = run_plr_simulation_grid(
    n_list, overlap_list, rho_list, n_rep=n_rep, random_state=42
)
summary_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 rho_list = [0.2, 0.5]
#       4 n_rep = 10
# ----> 6 results_df, summary_df = run_plr_simulation_grid(
#       7     n_list, overlap_list, rho_list, n_rep=n_rep, random_state=42
#       8 )
#       9 summary_df
#
# File ~/Documents/GitHub/dmlkappa/src/dmlkappa/simulation.py:207, in run_plr_simulation_grid(n_list, overlap_list, rho_list, n_rep, random_state)
#     205 rs_seed = rng.randint(0, 2 ** 31 - 1)
#     206 Y, D, X = simulate_plr_once(n=int(n), overlap=overlap, rho=float(rho), random_state=int(rs_seed))
# --> 207 out = fit_dml_plr(Y, D, X, n_folds=5, random_state=rs_seed)
#     208 theta_hat = out["theta_hat"]
#     209 se_hat = out["se_hat"]
#
# File ~/Documents/GitHub/dmlkappa/src/dmlkappa/simulation.py:166, in fit_dml_plr(Y, D, X, n_folds, learner, random_state)
#     164 m = RandomForestRegressor(random_state=random_state)
#     165 g = RandomForestRegressor(random_state=random_state)
# --> 166 m.fit(X[train_idx], D[train_idx])
#     167 g.fit(X[train_idx], Y[train_idx])
#     168 m_oof[test_idx] = m.predict(X[test_idx])
#
# File ~/anaconda3/envs/kappa/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/kappa/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:475, in BaseForest.fit(self, X, y, sample_weight)
#     470 if self.warm_start and len(self.estimators_) > 0:
#     471     # We draw from the random state to get the random state we
#     472     # would have got if we hadn't used a warm_start.
#     473     random_state.randint(MAX_INT, size=len(self.estimators_))
# --> 475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
#     486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#    (...)    504     for i, t in enumerate(trees)
#     505 )
#
# File ~/anaconda3/envs/kappa/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:476, in <listcomp>(.0)
#     470 if self.warm_start and len(self.estimators_) > 0:
#     471     # We draw from the random state to get the random state we
#     472     # would have got if we hadn't used a warm_start.
#     473     random_state.randint(MAX_INT, size=len(self.estimators_))
#     475 trees = [
# --> 476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
#     486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#    (...)    504     for i, t in enumerate(trees)
#     505 )
#
# File ~/anaconda3/envs/kappa/lib/python3.11/site-packages/sklearn/ensemble/_base.py:145, in BaseEnsemble._make_estimator(self, append, random_state)
#     142 estimator.set_params(**{p: getattr(self, p) for p in self.estimator_params})
#     144 if random_state is not None:
# --> 145     _set_random_states(estimator, random_state)
#     147 if append:
#     148     self.estimators_.append(estimator)
#
# File ~/anaconda3/envs/kappa/lib/python3.11/site-packages/sklearn/ensemble/_base.py:78, in _set_random_states(estimator, random_state)
#      75         to_set[key] = random_state.randint(np.iinfo(np.int32).max)
#      77 if to_set:
# ---> 78     estimator.set_params(**to_set)
#
# File ~/anaconda3/envs/kappa/lib/python3.11/site-packages/sklearn/base.py:338, in BaseEstimator.set_params(self, **params)
#     335 if not params:
#     336     # Simple optimization to gain speed (inspect is slow)
#     337     return self
# --> 338 valid_params = self.get_params(deep=True)
#     340 nested_params = defaultdict(dict)  # grouped by prefix
#     341 for key, value in params.items():
#
# File ~/anaconda3/envs/kappa/lib/python3.11/site-packages/sklearn/base.py:249, in BaseEstimator.get_params(self, deep)
#     234 """
#     235 Get parameters for this estimator.
#     236
#    (...)    246     Parameter names mapped to their values.
#     247 """
#     248 out = dict()
# --> 249 for key in self._get_param_names():
#     250     value = getattr(self, key)
#     251     if deep and hasattr(value, "get_params") and not isinstance(value, type):
#
# File ~/anaconda3/envs/kappa/lib/python3.11/site-packages/sklearn/base.py:218, in BaseEstimator._get_param_names(cls)
#     214 init_signature = inspect.signature(init)
#     215 # Consider the constructor parameters excluding 'self'
#     216 parameters = [
#     217     p
# --> 218     for p in init_signature.parameters.values()
#     219     if p.name != "self" and p.kind != p.VAR_KEYWORD
#     220 ]
#     221 for p in parameters:
#     222     if p.kind == p.VAR_POSITIONAL:
#
# File ~/anaconda3/envs/kappa/lib/python3.11/inspect.py:3015, in Signature.parameters(self)
#    3010     """Constructs Signature for the given callable object."""
#    3011     return _signature_from_callable(obj, sigcls=cls,
#    3012                                     follow_wrapper_chains=follow_wrapped,
#    3013                                     globals=globals, locals=locals, eval_str=eval_str)
# -> 3015 @property
#    3016 def parameters(self):
#    3017     return self._parameters
#    3019 @property
#    3020 def return_annotation(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. Plotting

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
plot_kappa_vs_coverage(summary_df, ax=axes[0])
plot_kappa_hist(results_df, ax=axes[1])
plt.tight_layout()
plt.show()
